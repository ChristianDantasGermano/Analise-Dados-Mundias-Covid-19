# %% [markdown]
# <h1>Análise dos dados mundiais do covid-19</h1>
#
# <h3>Disclaimer/Aviso Legal: Este notebook tem um fim única e exclusivamente didático, como uma introdução à Análise de Dados Públicos. Desse modo, está excluída a garantia ou responsabilidade de qualquer tipo, por exemplo, de precisão, confiabilidade, completude e atualidade das informações.</h3>
#
# Dados retirados do site https://covid19.who.int/
# <br>
# Ultima atualização dos dados: 12/07/2020
#
# Aluno: Christian Dantas Germano 3º ADS B
#
# Réferencia:
# https://github.com/Chrisdangermano/Analise-de-vendas-de-jogos

# %%
import pandas as pd
import matplotlib.pyplot as plt
low_memory=False
# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %%
filename = r'E:\EP04\covid19_globaldata.csv'
df = pd.read_csv(filename, delimiter=',', 
                 encoding='ISO-8859-1',
                 error_bad_lines=False)

# %%
df.shape
# Out:
# (27772, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27772 entries, 0 to 27771
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date_reported       27772 non-null  object
#  1    Country_code       27651 non-null  object
#  2    Country            27772 non-null  object
#  3    WHO_region         27772 non-null  object
#  4    New_cases          27772 non-null  int64
#  5    Cumulative_cases   27772 non-null  int64
#  6    New_deaths         27772 non-null  int64
#  7    Cumulative_deaths  27772 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 1.3+ MB

# %%
for par in enumerate(df.columns): print (par)
# Out:
# (0, 'Date_reported')
# (1, ' Country_code')
# (2, ' Country')
# (3, ' WHO_region')
# (4, ' New_cases')
# (5, ' Cumulative_cases')
# (6, ' New_deaths')
# (7, ' Cumulative_deaths')

# %%
#Tirando espaços das colunas
df.columns=['Date_reported','Country_code','Country','WHO_region','New_cases','Cumulative_cases','New_deaths','Cumulative_deaths']

# %%
for par in enumerate(df.columns): print (par)
# Out:
# (0, 'Date_reported')
# (1, 'Country_code')
# (2, 'Country')
# (3, 'WHO_region')
# (4, 'New_cases')
# (5, 'Cumulative_cases')
# (6, 'New_deaths')
# (7, 'Cumulative_deaths')

# %%
#Colocando o coluna de data em evidência
df2 = df.set_index('Date_reported')
df2.head(10)
# Out:
#               Country_code      Country WHO_region  New_cases  \
# Date_reported
# 2020-02-24              AF  Afghanistan       EMRO          1
# 2020-02-25              AF  Afghanistan       EMRO          0
# 2020-02-26              AF  Afghanistan       EMRO          0
# 2020-02-27              AF  Afghanistan       EMRO          0
# 2020-02-28              AF  Afghanistan       EMRO          0
# 2020-02-29              AF  Afghanistan       EMRO          0
# 2020-03-01              AF  Afghanistan       EMRO          0
# 2020-03-02              AF  Afghanistan       EMRO          0
# 2020-03-03              AF  Afghanistan       EMRO          0
# 2020-03-04              AF  Afghanistan       EMRO          0
#
#                Cumulative_cases  New_deaths  Cumulative_deaths
# Date_reported
# 2020-02-24                    1           0                  0
# 2020-02-25                    1           0                  0
# 2020-02-26                    1           0                  0
# 2020-02-27                    1           0                  0
# 2020-02-28                    1           0                  0
# 2020-02-29                    1           0                  0
# 2020-03-01                    1           0                  0
# 2020-03-02                    1           0                  0
# 2020-03-03                    1           0                  0
# 2020-03-04                    1           0                  0

# %%
#Determinado a data para uso dos dados
df2 = df2.loc['2020-07-11']
df2.sample(200)
# Out:
#               Country_code                             Country WHO_region  \
# Date_reported
# 2020-07-11              MF                        Saint Martin       AMRO
# 2020-07-11              VE  Venezuela (Bolivarian Republic of)       AMRO
# 2020-07-11              RU                  Russian Federation       EURO
# 2020-07-11              SV                         El Salvador       AMRO
# 2020-07-11              TH                            Thailand      SEARO
# ...                    ...                                 ...        ...
# 2020-07-11              GI                           Gibraltar       EURO
# 2020-07-11              CA                              Canada       AMRO
# 2020-07-11              PE                                Peru       AMRO
# 2020-07-11              SK                            Slovakia       EURO
# 2020-07-11              PH                         Philippines       WPRO
#
#                New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# Date_reported
# 2020-07-11             0                44           0                  3
# 2020-07-11           362              8372           5                 80
# 2020-07-11          6611            720547         188              11205
# 2020-07-11           298              9142           6                249
# 2020-07-11            14              3216           0                 58
# ...                  ...               ...         ...                ...
# 2020-07-11             1               180           0                  0
# 2020-07-11           371            106805          12               8749
# 2020-07-11          3537            316448         181              11314
# 2020-07-11            19              1870           0                 28
# 2020-07-11          1160             52914          42               1360
#
# [200 rows x 7 columns]

# %% [markdown]
# <h2><center>Países com mais mortes</center></h2>

# %%
plt.style.use('seaborn-dark-palette')
df2.groupby('Country')['Cumulative_deaths'].max().sort_values().tail(10).plot(kind='barh', figsize=(12, 12))

# %% [markdown]
# <h2><center>Países com mais casos</center></h2>

# %%
plt.style.use('bmh')
df2.groupby('Country')['Cumulative_cases'].max().sort_values().tail(10).plot(kind='barh', figsize=(12, 12))

# %% [markdown]
# <h2><center>Brasil</center></h2>

# %%
#Mudando tabela para apenas todos os dados do brasil
dft = df.set_index('Country')
dft = dft.loc['Brazil']
dft.head(10)
# Out:
#         Date_reported Country_code WHO_region  New_cases  Cumulative_cases  \
# Country
# Brazil     2020-02-26           BR       AMRO          1                 1
# Brazil     2020-02-27           BR       AMRO          0                 1
# Brazil     2020-02-28           BR       AMRO          0                 1
# Brazil     2020-02-29           BR       AMRO          0                 1
# Brazil     2020-03-01           BR       AMRO          1                 2
# Brazil     2020-03-02           BR       AMRO          0                 2
# Brazil     2020-03-03           BR       AMRO          0                 2
# Brazil     2020-03-04           BR       AMRO          1                 3
# Brazil     2020-03-05           BR       AMRO          4                 7
# Brazil     2020-03-06           BR       AMRO          1                 8
#
#          New_deaths  Cumulative_deaths
# Country
# Brazil            0                  0
# Brazil            0                  0
# Brazil            0                  0
# Brazil            0                  0
# Brazil            0                  0
# Brazil            0                  0
# Brazil            0                  0
# Brazil            0                  0
# Brazil            0                  0
# Brazil            0                  0

# %% [markdown]
# <h2><center>Casos nos últimos 15 dias</center></h2>

# %%
plt.style.use('bmh')
dft.groupby('Date_reported')['New_cases'].max().tail(15).plot(kind='bar', figsize=(12, 12))

# %% [markdown]
# <h2><center>Mortes nos últimos 15 dias</center></h2>

# %%
plt.style.use('seaborn-dark-palette')
dft.groupby('Date_reported')['New_deaths'].max().tail(15).plot(kind='bar', figsize=(12, 12))

# %% [markdown]
# <h2><center>Estados Unidos</center></h2>

# %%
#Mudando tabela para apenas todos os dados do Estados Unidos
dft = df.set_index('Country')
dft = dft.loc['United States of America']
dft.head(10)
# Out:
#                          Date_reported Country_code WHO_region  New_cases  \
# Country
# United States of America    2020-01-20           US       AMRO          1
# United States of America    2020-01-21           US       AMRO          0
# United States of America    2020-01-22           US       AMRO          0
# United States of America    2020-01-23           US       AMRO          0
# United States of America    2020-01-24           US       AMRO          1
# United States of America    2020-01-25           US       AMRO          0
# United States of America    2020-01-26           US       AMRO          3
# United States of America    2020-01-27           US       AMRO          0
# United States of America    2020-01-28           US       AMRO          0
# United States of America    2020-01-29           US       AMRO          0
#
#                           Cumulative_cases  New_deaths  Cumulative_deaths
# Country
# United States of America                 1           0                  0
# United States of America                 1           0                  0
# United States of America                 1           0                  0
# United States of America                 1           0                  0
# United States of America                 2           0                  0
# United States of America                 2           0                  0
# United States of America                 5           0                  0
# United States of America                 5           0                  0
# United States of America                 5           0                  0
# United States of America                 5           0                  0

# %% [markdown]
# <h2><center>Casos nos últimos 15 dias</center></h2>

# %%
plt.style.use('bmh')
dft.groupby('Date_reported')['New_cases'].max().tail(15).plot(kind='bar', figsize=(12, 12))

# %% [markdown]
# <h2><center>Mortes nos últimos 15 dias</center></h2>

# %%
plt.style.use('seaborn-dark-palette')
dft.groupby('Date_reported')['New_deaths'].max().tail(15).plot(kind='bar', figsize=(12, 12))
